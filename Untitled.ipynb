# %%
import cv2
from darkflow.net.build import TFNet
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/god/yolo/darkflow/darkflow/net/build.py:15: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /home/god/yolo/darkflow/darkflow/net/build.py:16: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# WARNING:tensorflow:From /home/god/yolo/darkflow/darkflow/net/build.py:17: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /home/god/yolo/darkflow/darkflow/net/build.py:18: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
#
# WARNING:tensorflow:From /home/god/yolo/darkflow/darkflow/net/build.py:19: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.
#
# WARNING:tensorflow:From /home/god/yolo/darkflow/darkflow/net/build.py:20: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/god/yolo/darkflow/darkflow/net/build.py:21: The name tf.train.FtrlOptimizer is deprecated. Please use tf.compat.v1.train.FtrlOptimizer instead.
#
# WARNING:tensorflow:From /home/god/yolo/darkflow/darkflow/net/build.py:22: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
options = {
    'model':'cfg/tiny-yolo-voc-1c.cfg',
    'load':'bin/tiny-yolo-voc.weights',
    'threshold':0.6
}

tfnet = TFNet(options)
# Out:
# Parsing ./cfg/tiny-yolo-voc.cfg
# Parsing cfg/tiny-yolo-voc-1c.cfg
# Loading bin/tiny-yolo-voc.weights ...
# Successfully identified 63471556 bytes
# Finished in 0.006053447723388672s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 26, 26, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 13, 13, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | maxp 2x2p0_1                     | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 1x1p0_1    linear           | (?, 13, 13, 30)
# -------+--------+----------------------------------+---------------
# Running entirely on CPU
# Finished in 1.571293592453003s

# %%
img = cv2.imread('image.jpeg',cv2.IMREAD_COLOR)
res = tfnet.return_predict(img)

res
# Out:
# [{'label': 'damage',
#   'confidence': 0.60372263,
#   'topleft': {'x': 0, 'y': 0},
#   'bottomright': {'x': 253, 'y': 58}},
#  {'label': 'damage',
#   'confidence': 0.6480238,
#   'topleft': {'x': 176, 'y': 41},
#   'bottomright': {'x': 205, 'y': 50}},
#  {'label': 'damage',
#   'confidence': 0.60009086,
#   'topleft': {'x': 57, 'y': 0},
#   'bottomright': {'x': 293, 'y': 90}},
#  {'label': 'damage',
#   'confidence': 0.6630071,
#   'topleft': {'x': 146, 'y': 53},
#   'bottomright': {'x': 190, 'y': 65}},
#  {'label': 'damage',
#   'confidence': 0.66431534,
#   'topleft': {'x': 170, 'y': 54},
#   'bottomright': {'x': 211, 'y': 64}}]

# %%
for i in res:

# %%
t1 = (res[4]['topleft']['x'],res[4]['topleft']['y'])
t2 = (res[4]['bottomright']['x'],res[4]['bottomright']['y'])
label = res[4]['label']
img = cv2.rectangle(img,t1,t2,(255,0,0),2)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
